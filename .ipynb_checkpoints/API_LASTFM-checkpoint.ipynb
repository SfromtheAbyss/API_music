# %%
import requests
import json
import time
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

API_KEY = '1a9ea75b5f92dfda381d817fc00e5458' 
USER_AGENT = '808e0a8bbaf9d30bf181edb60c742824'  
LIMIT = 10  ##Número de resultados a obtener

headers = {
    'user-agent': USER_AGENT
}

##sacar top artists
def get_top_artists():
    params = {
        'method': 'chart.getTopArtists',
        'api_key': API_KEY,
        'format': 'json',
        'limit': LIMIT
    }
    response = requests.get('https://ws.audioscrobbler.com/2.0/', headers=headers, params=params)
    if response.status_code == 200:
        data = response.json()
        df = pd.json_normalize(data['artists']['artist'])
    else:
        print(f"Error en la solicitud de top artistas globales: {response.status_code}")
    time.sleep(1)
    return df

##sacar top artistas por pais
def get_top_artists_by_country(country):
    params = {
        'method': 'geo.getTopArtists',
        'country': country,
        'api_key': API_KEY,
        'format': 'json',
        'limit': LIMIT
    }
    response = requests.get('https://ws.audioscrobbler.com/2.0/', headers=headers, params=params)
    if response.status_code == 200:
        data = response.json()
        df = pd.json_normalize(data['topartists']['artist'])
    else:
        print(f"Error en la solicitud de top artistas por país: {response.status_code}")
    time.sleep(1)
    return df

##sacar top canciones por pais
def get_top_tracks_by_country(country):
    params = {
        'method': 'geo.getTopTracks',
        'country': country,
        'api_key': API_KEY,
        'format': 'json',
        'limit': LIMIT
    }
    response = requests.get('https://ws.audioscrobbler.com/2.0/', headers=headers, params=params)
    if response.status_code == 200:
        data = response.json()
        df = pd.json_normalize(data['tracks']['track'])
    else:
        print(f"Error en la solicitud de top canciones por país: {response.status_code}")
    time.sleep(1)
    return df

##sacar top album de x artista
def get_top_albums_by_artist(artist):
    params = {
        'method': 'artist.getTopAlbums',
        'artist': artist,
        'api_key': API_KEY,
        'format': 'json',
        'limit': LIMIT
    }
    response = requests.get('https://ws.audioscrobbler.com/2.0/', headers=headers, params=params)
    if response.status_code == 200:
        data = response.json()
        df = pd.json_normalize(data['topalbums']['album'])
    else:
        print(f"Error en la solicitud de top álbumes del artista: {response.status_code}")
    time.sleep(1)
    return df

# %%
df_top_artist = get_top_artists()
df_top_artist
# Out:
#                  name   playcount listeners  \
# 0      Kendrick Lamar   818756652   4427265
# 1           Lady Gaga   743981717   6729261
# 2          The Weeknd   874127438   4593275
# 3  Tyler, the Creator   788106822   3633018
# 4       Billie Eilish   647481270   3589324
# 5          Charli XCX   520353469   3143713
# 6           Radiohead  1034205621   7167322
# 7        Lana Del Rey  1232800213   4593272
# 8          Kanye West  1240674209   7142300
# 9             Rihanna   452145471   7324573
#
#                                    mbid  \
# 0  381086ea-f511-4aba-bdf9-71c753dc5077
# 1  650e7db6-b795-4eb5-a702-5ea2fc46c848
# 2  c8b03190-306c-4120-bb0b-6f2ebfc06ea9
# 3  f6beac20-5dfe-4d1f-ae02-0b0a740aafd6
# 4
# 5  260b6184-8828-48eb-945c-bc4cb6fc34ca
# 6  a74b1b7f-71a5-4011-9441-d0b5e4122711
# 7  b7539c32-53e7-4908-bda3-81449c367da6
# 8  164f0d73-1234-4e2c-8743-d77bf2191051
# 9  db36a76f-4cdf-43ac-8cd0-5e48092d2bae
#
#                                             url streamable  \
# 0      https://www.last.fm/music/Kendrick+Lamar          0
# 1           https://www.last.fm/music/Lady+Gaga          0
# 2          https://www.last.fm/music/The+Weeknd          0
# 3  https://www.last.fm/music/Tyler,+the+Creator          0
# 4       https://www.last.fm/music/Billie+Eilish          0
# 5          https://www.last.fm/music/Charli+XCX          0
# 6           https://www.last.fm/music/Radiohead          0
# 7        https://www.last.fm/music/Lana+Del+Rey          0
# 8          https://www.last.fm/music/Kanye+West          0
# 9             https://www.last.fm/music/Rihanna          0
#
#                                                image
# 0  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 1  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 2  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 3  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 4  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 5  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 6  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 7  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 8  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 9  [{'#text': 'https://lastfm.freetls.fastly.net/...

# %%
get_top_artists_by_country("Spain")
# Out:
#                  name listeners                                  mbid  \
# 0         David Bowie   4935464  5441c29d-3602-4898-b1a1-b77fa23b8e50
# 1            Coldplay   8021868  cc197bad-dc9c-440d-a5b5-d52ba2e14234
# 2               Queen   6351905  420ca290-76c5-41af-999e-564d7c71f1a7
# 3           Radiohead   7167322  a74b1b7f-71a5-4011-9441-d0b5e4122711
# 4  The Rolling Stones   5336259  b071f9fa-14b0-4217-8e97-eb41da73f598
# 5         The Beatles   5748282  b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d
# 6                Muse   5568975  fd857293-5ab8-40de-b29e-55a69d4e4d0f
# 7            The Cure   4736891  69ee3720-a7cb-4402-b48d-a02c366f2bcf
# 8           Daft Punk   5589702  056e4f3e-d505-4dad-8ec1-d04f521cbb56
# 9          The Weeknd   4593275  c8b03190-306c-4120-bb0b-6f2ebfc06ea9
#
#                                             url streamable  \
# 0         https://www.last.fm/music/David+Bowie          0
# 1            https://www.last.fm/music/Coldplay          0
# 2               https://www.last.fm/music/Queen          0
# 3           https://www.last.fm/music/Radiohead          0
# 4  https://www.last.fm/music/The+Rolling+Stones          0
# 5         https://www.last.fm/music/The+Beatles          0
# 6                https://www.last.fm/music/Muse          0
# 7            https://www.last.fm/music/The+Cure          0
# 8           https://www.last.fm/music/Daft+Punk          0
# 9          https://www.last.fm/music/The+Weeknd          0
#
#                                                image
# 0  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 1  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 2  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 3  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 4  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 5  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 6  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 7  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 8  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 9  [{'#text': 'https://lastfm.freetls.fastly.net/...

# %%
get_top_tracks_by_country("Spain")
# Out:
#                          name duration listeners  \
# 0                       Creep      239   3308693
# 1                 Take Me Out      256   2637823
# 2           Seven Nation Army      449   2548195
# 3  The Less I Know the Better        0   2184272
# 4     Smells Like Teen Spirit      301   3547430
# 5          Losing My Religion      301   2044732
# 6                   Last Nite        0   1849012
# 7                  Lonely Boy      193   1288799
# 8                Karma Police        0   2773004
# 9            Do I Wanna Know?      272   2468030
#
#                                    mbid  \
# 0  d11fcceb-dfc5-4d19-b45d-f4e8f6d3eaa6
# 1  11b7c3d2-8a49-4812-95dc-aef93c4cec37
# 2  24cc8311-98fd-423a-bed1-97728f5eabc5
# 3
# 4  0ebe2d92-a11d-4b2b-9922-806383074ed7
# 5  04233db6-f991-4fb2-bef9-813f95a0bf30
# 6  4ce968a0-4e52-40e3-9f77-1b726200a3c0
# 7  d6df9a96-5e7c-44dd-8672-9c16c746016d
# 8  0790ba6c-e0b1-4891-b82f-b4db9a5a927f
# 9  f1e57531-e0df-4b3e-938f-1ae30c5b1a11
#
#                                                  url  \
# 0        https://www.last.fm/music/Radiohead/_/Creep
# 1  https://www.last.fm/music/Franz+Ferdinand/_/Ta...
# 2  https://www.last.fm/music/The+White+Stripes/_/...
# 3  https://www.last.fm/music/Tame+Impala/_/The+Le...
# 4  https://www.last.fm/music/Nirvana/_/Smells+Lik...
# 5  https://www.last.fm/music/R.E.M./_/Losing+My+R...
# 6  https://www.last.fm/music/The+Strokes/_/Last+Nite
# 7  https://www.last.fm/music/The+Black+Keys/_/Lon...
# 8  https://www.last.fm/music/Radiohead/_/Karma+Po...
# 9  https://www.last.fm/music/Arctic+Monkeys/_/Do+...
#
#                                                image streamable.#text  \
# 0  [{'#text': 'https://lastfm.freetls.fastly.net/...                0
# 1  [{'#text': 'https://lastfm.freetls.fastly.net/...                0
# 2  [{'#text': 'https://lastfm.freetls.fastly.net/...                0
# 3  [{'#text': 'https://lastfm.freetls.fastly.net/...                0
# 4  [{'#text': 'https://lastfm.freetls.fastly.net/...                0
# 5  [{'#text': 'https://lastfm.freetls.fastly.net/...                0
# 6  [{'#text': 'https://lastfm.freetls.fastly.net/...                0
# 7  [{'#text': 'https://lastfm.freetls.fastly.net/...                0
# 8  [{'#text': 'https://lastfm.freetls.fastly.net/...                0
# 9  [{'#text': 'https://lastfm.freetls.fastly.net/...                0
#
#   streamable.fulltrack        artist.name  \
# 0                    0          Radiohead
# 1                    0    Franz Ferdinand
# 2                    0  The White Stripes
# 3                    0        Tame Impala
# 4                    0            Nirvana
# 5                    0             R.E.M.
# 6                    0        The Strokes
# 7                    0     The Black Keys
# 8                    0          Radiohead
# 9                    0     Arctic Monkeys
#
#                             artist.mbid  \
# 0  a74b1b7f-71a5-4011-9441-d0b5e4122711
# 1  aa7a2827-f74b-473c-bd79-03d065835cf7
# 2  11ae9fbb-f3d7-4a47-936f-4c0a04d3b3b5
# 3  63aa26c3-d59b-4da4-84ac-716b54f1ef4d
# 4  9282c8b4-ca0b-4c6b-b7e3-4f7762dfc4d6
# 5  ea4dfa26-f633-4da6-a52a-f49ea4897b58
# 6  f181961b-20f7-459e-89de-920ef03c7ed0
# 7  d15721d8-56b4-453d-b506-fc915b14cba2
# 8  a74b1b7f-71a5-4011-9441-d0b5e4122711
# 9  ada7a83c-e3e1-40f1-93f9-3e73dbc9298a
#
#                                     artist.url @attr.rank
# 0          https://www.last.fm/music/Radiohead          0
# 1    https://www.last.fm/music/Franz+Ferdinand          1
# 2  https://www.last.fm/music/The+White+Stripes          2
# 3        https://www.last.fm/music/Tame+Impala          3
# 4            https://www.last.fm/music/Nirvana          4
# 5             https://www.last.fm/music/R.E.M.          5
# 6        https://www.last.fm/music/The+Strokes          6
# 7     https://www.last.fm/music/The+Black+Keys          7
# 8          https://www.last.fm/music/Radiohead          8
